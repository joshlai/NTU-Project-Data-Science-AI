# %%
# Getting API access for gov or yahoo stock data


# creation of Lamda server to run code


# pulling of data


# denorminatilization of data - creation of table


# inspection of data for missiing values and data quality 


# ETL pipe line


# setting of of data warehouse
